# %% [markdown]
# <a href="https://colab.research.google.com/github/jjayli/data-scraper/blob/main/youtube_mp3_downloader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. yt-dlp 설치
# !pip install yt-dlp

# 2. ffmpeg 설치 (코랩 기본 환경에 이미 있을 수 있지만 최신화를 위해 실행)
# !apt-get update -y
# !apt-get install ffmpeg -y
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.3/180.3 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 8.3 MB/s eta 0:00:00
# ...
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [345 B]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,205 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,556 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# ...

# %%
import yt_dlp
from google.colab import files
import os

def download_youtube_as_mp3():
    # 1. 유튜브 URL 입력받기
    url = input("추출하고 싶은 유튜브 URL을 입력하세요: ")

    # 2. 저장 설정 (고음질 320kbps MP3)
    ydl_opts = {
        'format': 'bestaudio/best',
        'postprocessors': [{
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'mp3',
            'preferredquality': '320',
        }],
        'outtmpl': '%(title)s.%(ext)s',

        # 재생목록 무시 설정 추가
        'noplaylist': True,
    }

    try:
        print(f"\n'{url}' 에서 오디오 추출을 시작합니다...")

        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            # 정보 가져오기 및 다운로드
            info = ydl.extract_info(url, download=True)
            filename = ydl.prepare_filename(info)

            # 파일명 확장자 mp3로 변경
            base, ext = os.path.splitext(filename)
            mp3_filename = base + ".mp3"

            print(f"\n변환 완료: {mp3_filename}")

            # 3. 브라우저로 파일 내보내기
            print("파일 다운로드를 시작합니다...")
            files.download(mp3_filename)

    except Exception as e:
        print(f"오류가 발생했습니다: {e}")

# 함수 실행
download_youtube_as_mp3()
# Out:
# 추출하고 싶은 유튜브 URL을 입력하세요: https://www.youtube.com/watch?v=e1htZET1j2Y&list=RDe1htZET1j2Y&start_radio=1
#
# 'https://www.youtube.com/watch?v=e1htZET1j2Y&list=RDe1htZET1j2Y&start_radio=1' 에서 오디오 추출을 시작합니다...
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=e1htZET1j2Y&list=RDe1htZET1j2Y&start_radio=1
# [youtube:tab] Downloading just the video e1htZET1j2Y because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=e1htZET1j2Y
# [youtube] e1htZET1j2Y: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] e1htZET1j2Y: Downloading android sdkless player API JSON
# ...
